# %%
from Abs_LR_module import absenteeism_model,CustomScaler
import pandas as pd

# %%
df=pd.read_csv('Absenteeism_new_data.csv')
df1=pd.read_csv('Absenteeism_data.csv')
df1
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# ..   ..                 ...         ...                     ...
# 695  17                  10  23/05/2018                     179
# 696  28                   6  23/05/2018                     225
# 697  18                  10  24/05/2018                     330
# 698  25                  23  24/05/2018                     235
# 699  15                  28  31/05/2018                     291
#
#      Distance to Work  Age  Daily Work Load Average  Body Mass Index  \
# 0                  36   33                  239.554               30
# ...

# %%
df
# Out:
#     ID  Reason for Absence        Date  Transportation Expense  \
# 0   22                  27  01/06/2018                     179
# 1   10                   7  04/06/2018                     361
# 2   14                  23  06/06/2018                     155
# 3   17                  25  08/06/2018                     179
# 4   14                  10  08/06/2018                     155
# 5   28                  11  11/06/2018                     225
# 6   16                   7  13/06/2018                     118
# 7   22                  27  13/06/2018                     179
# 8   34                  26  15/06/2018                     118
# 9   34                  10  20/06/2018                     118
# 10  23                  22  21/06/2018                     378
# 11  36                  19  21/06/2018                     118
# 12  12                  19  22/06/2018                     233
# 13  22                  27  22/06/2018                     179
# ...

# %%
model = absenteeism_model('Abs_model','Abs_scaler')
model2 = absenteeism_model('Abs_model','Abs_scaler')

# %%
model2.load_and_clean_data('Absenteeism_data.csv')
model.load_and_clean_data('Absenteeism_new_data.csv')

# %%
df_new_obs = model.predicted_outputs()
df_new_obs2 = model2.predicted_outputs()

# %%
print(df_new_obs.columns)
print(df_new_obs2.columns)
# Out:
# Index(['rg1', 'rg2', 'rg3', 'rg4', 'month_value', 'Transportation Expense',
#        'Age', 'Body Mass Index', 'Education', 'Children', 'Pets',
#        'Probability', 'Prediction'],
#       dtype='object')
# Index(['rg1', 'rg2', 'rg3', 'rg4', 'month_value', 'Transportation Expense',
#        'Age', 'Body Mass Index', 'Education', 'Children', 'Pets',
#        'Probability', 'Prediction'],
#       dtype='object')

# %%
import pymysql as sql

# %%
conn = sql.connect(database = 'predicted_outputs', user = 'root',password = 'sharanyu')

# %%
cur= conn.cursor()

# %%
cur.execute('Select * from predicted_outputs;')
# Out:
# 0

# %%
df_new_obs.shape[0]
# Out:
# 40

# %%
df_new_obs
# Out:
#     rg1  rg2  rg3  rg4  month_value  Transportation Expense  Age  \
# 0     1  0.0  0.0  0.0            6                     179   30
# 1     1  0.0  0.0  0.0            6                     361   28
# 2     1  0.0  0.0  0.0            6                     155   34
# 3     1  0.0  0.0  0.0            6                     179   40
# 4     1  0.0  0.0  0.0            6                     155   34
# 5     1  0.0  0.0  0.0            6                     225   28
# 6     1  0.0  0.0  0.0            6                     118   46
# 7     1  0.0  0.0  0.0            6                     179   30
# 8     1  0.0  0.0  0.0            6                     118   37
# 9     1  0.0  0.0  0.0            6                     118   37
# 10    1  0.0  0.0  0.0            6                     378   36
# 11    1  0.0  0.0  0.0            6                     118   50
# 12    1  0.0  0.0  0.0            6                     233   31
# ...

# %%
df_new_obs2
# Out:
#      rg1  rg2  rg3  rg4  month_value  Transportation Expense  Age  \
# 0      0    0    0    1            7                     289   33
# 1      0    0    0    0            7                     118   50
# 2      0    0    0    1            7                     179   38
# 3      1    0    0    0            7                     279   39
# 4      0    0    0    1            7                     289   33
# 5      0    0    0    1            7                     179   38
# 6      0    0    0    1            7                     361   28
# 7      0    0    0    1            7                     260   36
# 8      0    0    1    0            7                     155   34
# 9      0    0    0    1            7                     235   37
# 10     1    0    0    0            7                     260   36
# 11     1    0    0    0            7                     260   36
# 12     1    0    0    0            7                     260   36
# ...

# %%
insert = 'INSERT INTO predicted_outputs VALUES '

# %%
for i in range(df_new_obs2.shape[0]):
    insert+= '(' 
    
    for j in range(df_new_obs2.shape[1]):
        insert+= str(df_new_obs2[df_new_obs2.columns.values[j]][i]) + ', '
    
    insert= insert[:-2] + '), '

# %%
insert = insert[:-2] + ';'
insert
# Out:
# 'INSERT INTO predicted_outputs VALUES (0, 0, 0, 1, 7, 289, 33, 30, 0, 2, 1, 0.5908240518056092, 1), (0, 0, 0, 0, 7, 118, 50, 31, 0, 1, 0, 0.07612942327810328, 0), (0, 0, 0, 1, 7, 179, 38, 31, 0, 0, 0, 0.2509636846725263, 0), (1, 0, 0, 0, 7, 279, 39, 24, 0, 2, 0, 0.8721941731022985, 1), (0, 0, 0, 1, 7, 289, 33, 30, 0, 2, 1, 0.5908240518056092, 1), (0, 0, 0, 1, 7, 179, 38, 31, 0, 0, 0, 0.2509636846725263, 0), (0, 0, 0, 1, 7, 361, 28, 27, 0, 1, 4, 0.4833424494340947, 0), (0, 0, 0, 1, 7, 260, 36, 23, 0, 4, 0, 0.605059882766098, 1), (0, 0, 1, 0, 7, 155, 34, 25, 0, 2, 0, 0.7862189536134984, 1), (0, 0, 0, 1, 7, 235, 37, 29, 1, 1, 1, 0.30530218537095255, 0), (1, 0, 0, 0, 7, 260, 36, 23, 0, 4, 0, 0.9158914621798258, 1), (1, 0, 0, 0, 7, 260, 36, 23, 0, 4, 0, 0.9158914621798258, 1), (1, 0, 0, 0, 7, 260, 36, 23, 0, 4, 0, 0.9158914621798258, 1), (1, 0, 0, 0, 7, 179, 38, 31, 0, 0, 0, 0.7042704899938933, 1), (0, 0, 0, 1, 7, 179, 38, 31, 0, 0, 0, 0.2509636846725263, 0), (1, 0, 0, 0, 7, 246, 41, 23, 
# ...

# %%
cur.execute(insert)
# Out:
# 700

# %%
conn.commit()

# %%
conn.close()
